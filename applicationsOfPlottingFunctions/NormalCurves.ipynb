# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_csv("/content/adult.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28855 entries, 0 to 28854
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              28855 non-null  int64
#  1   workclass        28855 non-null  object
#  2   fnlwgt           28855 non-null  int64
#  3   education        28855 non-null  object
#  4   educational-num  28855 non-null  int64
#  5   marital-status   28855 non-null  object
#  6   occupation       28855 non-null  object
#  7   relationship     28855 non-null  object
#  8   race             28854 non-null  object
#  9   gender           28855 non-null  object
#  10  capital-gain     28855 non-null  object
#  11  capital-loss     28854 non-null  object
#  12  hours-per-week   28853 non-null  object
#  13  native-country   28852 non-null  object
#  14  income           28852 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 3.3+ MB

# %%
sns.set(font_scale=0.5)

# %%
df
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 28850   26    Private  240842       HS-grad                9
# 28851   53    Private  103931  Some-college               10
# 28852   60    Private  232618     Bachelors               13
# 28853   49  Local-gov  288548       Masters               14
# 28854   40    Private  220609  Some-college               10
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
sns.catplot(x="relationship",y="age",data=df,kind="point",hue="income")

# %%
sns.relplot(x="educational-num",y="hours-per-week",data=df,kind="line",hue="relationship")
